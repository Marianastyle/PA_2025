# %% [markdown]
# <a href="https://colab.research.google.com/github/Marianastyle/PA_2025/blob/main/C%C3%B3pia_de_atividades_aula_22_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exercícios com for, while, listas, strings e dicionários**

# %% [markdown]
# 1) Soma dos números de uma lista
#
# Dada a lista numeros = [3, 7, 2, 8, 10], use um for para calcular a soma de todos os elementos.

# %%
lista=[3,7,2,8,10]
for i in lista:
  soma=0
soma=soma+i
print(soma)
# Out:
# 10

# %% [markdown]
# 2) Contagem de vogais em uma string
#
# Peça uma palavra ao usuário e use um for para contar quantas vogais (a, e, i, o, u) existem.

# %%
pal=str(input("digite uma palavra: "))
vogais=["a","e","i","o","u"]
conta=0
for p in pal:
  if p in vogais:
    conta+=1
print("a palavra tem: ",conta, "vogais")
# Out:
# digite uma palavra: abacaxi
# a palavra tem:  4 vogais

# %% [markdown]
# 3) Inverter lista usando while
#
# Dada a lista nomes = ["Ana", "João", "Carlos", "Maria"], use um while para inverter a ordem dos elementos (sem usar reverse() ou slicing).

# %%
nomes = ["Ana", "João", "Carlos", "Maria"]
while i in nomes:

# %% [markdown]
# 4) Maior número em uma lista
#
# Escreva um programa que percorra uma lista de inteiros e encontre o maior valor.

# %%
 lista=[1,2,3,4,50,30,13,27]
max(lista)
# Out:
# 50

# %% [markdown]
# 5) Remover elementos repetidos de uma lista
#
# Usando um for, percorra a lista valores = [1, 2, 2, 3, 4, 4, 5] e crie uma nova lista apenas com elementos únicos.

# %%
valores =[1, 2, 2, 3, 4, 4, 5]
remov=[]
for i in valores:
# Out:
#   File "/tmp/ipython-input-133381398.py", line 3
#     for i in valores:
#                      ^
# SyntaxError: incomplete input

# %% [markdown]
# 6) Verificar se palavra é palíndromo
#
# Peça uma palavra ao usuário e use while ou for para verificar se ela é igual de frente para trás (ex.: "arara").

# %%
 pala=int(input("digite uma palavra: "))
 palap=""
 for i in pala:
  pala.lower()
if pala[::-1]==i[::-1]:
# Out:
#   File "/tmp/ipython-input-4177433926.py", line 7
#
#     ^
# SyntaxError: incomplete input

# %% [markdown]
# 7 Contagem regressiva com while
#
# Peça ao usuário um número e faça uma contagem regressiva até 0.

# %%
 numero =0
 numero=int(input("digite um numero: "))
while i in numero:
  [numero,0]
# Out:
# digite um numero: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1863673139.py in <cell line: 0>()
#       1 numero =0
#       2 numero=int(input("digite um numero: "))
# ----> 3 while i in numero:
#       4  [numero,0]
#
# TypeError: argument of type 'int' is not iterable

# %% [markdown]
# 8) Percorrendo um dicionário de notas
#
# Dado o dicionário notas = {"Ana": 8, "Carlos": 7, "Maria": 10}, use um for para exibir cada aluno com sua nota.

# %%
notas = {"Ana": 8, "Carlos": 7, "Maria": 10}
for nome,nume, in notas.items():
  print("o nome do aluno(a) é: ",nome,"a nota é: ",nume,)
# Out:
# o nome do aluno(a) é:  Ana a nota é:  8
# o nome do aluno(a) é:  Carlos a nota é:  7
# o nome do aluno(a) é:  Maria a nota é:  10

# %% [markdown]
# 9)Filtrar números pares de uma lista
#
# Dada a lista numeros = [10, 21, 32, 43, 54], use um for para criar uma nova lista contendo apenas os pares.

# %%
numeros = [10, 21, 32, 43, 54]
numpares=[]
for i in numeros:
  resto=(i%2)
  if resto == 0:
    numpares.append(i)
print("os numeros pares são: ",numpares)
# Out:
# os numeros pares são:  [10, 32, 54]

# %% [markdown]
# 10) Contador de palavras em uma frase
#
# Peça ao usuário uma frase, divida em palavras (split()) e use um dicionário para contar quantas vezes cada palavra aparece.

# %%
frase=str(input("digite uma frase: "))
frase.slipt(",")
# Out:
# digite uma frase: eu amo cozinhar
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2072174739.py in <cell line: 0>()
#       1 frase=str(input("digite uma frase: "))
# ----> 2 frase.slipt()
#
# AttributeError: 'str' object has no attribute 'slipt'
