# %% [markdown]
# <a href="https://colab.research.google.com/github/Marianastyle/PA_2025/blob/main/auladefluxogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #calculo media

# %%
# recebe as notas das provas
nota1 = float(input("Digite a nota da P1: "))
nota2 = float(input("Digite a nota da P2: "))
# Out:
# Digite a nota da P1: 10
# Digite a nota da P2: 7

# %%
# Calcula a media
media = (nota1 + nota2) / 2

# %%
# mostra a media
print(f"a media é: {media}")
# Out:
# a media é: 8.5

# %% [markdown]
# #conversao moeda

# %%
# Recebe a cotacao do dolar e o valor em reais
cotacao_dolar = float(input("Digite a cotacao do dolar: "))
valor_reais = float(input("Digite o valor em reais: "))
# Out:
# Digite a cotacao do dolar: 5.73
# Digite o valor em reais: 50

# %%
# converte para dolares
valor_dolar = valor_reais / cotacao_dolar

# %%
# mostra o resultado
print(f"O valor em dolares é:${valor_dolar:.2f}")
# Out:
# O valor em dolares é:$8.73

# %% [markdown]
# #comissao

# %%
# recebe o preço unitario e a quantidade vendida
preco_unitario = float(input("Digite o preco unitario da peca: "))
quantidade_vendida = int(input("Digite a quantidade vendida: "))
# Out:
# Digite o preco unitario da peca: 150
# Digite a quantidade vendida: 3

# %%
# calcula o valor total da venda e a comissao
valor_total_venda = preco_unitario * quantidade_vendida
comissao = valor_total_venda * 0.05

# %%
# mostra os resultados
print(f"Valor total da venda: R${valor_total_venda:.2f}")
print(f"comissao do vendedor:R${comissao:.2f}")
# Out:
# Valor total da venda: R$450.00
# comissao do vendedor:R$22.50

# %% [markdown]
# # Exercicio 1
# O custo ao consumidor de um carro novo é a soma do custo de fábrica com a percentagem do distribuidor e dos impostos (aplicados, primeiro os impostos sobre o custo de fábrica, e depois a percentagem do distribuidor sobre o resultado). Supondo que a percentagem do distribuidor seja de 28% e os impostos 45%. Escrever um algoritmo que leia o custo de fábrica de um carro e informe o custo ao consumidor do mesmo.

# %%
#entrada
valorcarro=int(input("digite o valor do carro"))
#processamento
imposto=(valorcarro*45/100)+valorcarro
valorfinal=(imposto*28/100)+imposto
#saida
print(f"o valorfinal é:{valorfinal}")
# Out:
# digite o valor do carro25000
# o valorfinal é:46400.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercicio 2
# Faça um algoritmo que faça conversão de minutos e horas em segundos. Solicite ao usuário a hora e os minutos separado.

# %%
#entrada
hora = int(input("digite a hora"))
min = int(input("digite os minutos"))
#processamento
convertido = hora + (min/60)
#saida
print(f"a hora convertida é:{convertido}")
# Out:
# digite a hora4
# digite os minutos23
# a hora convertida é:4.383333333333334

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercicio 3
# Continuando do exercício anterior, um funcionário trabalha em determinada empresa e quer saber quanto irá ganhar de hora extra. Você deverá fazer um algoritmo que solicite quantas horas e quantos minutos ele trabalhou, solicite horas e minutos de forma separada. Depois pergunte quanto ele ganha por hora e informe quanto ele irá ganhar. Sabendo que nessa empresa o funcionário ganha 70% a mais pelas horas trabalhadas.

# %%
#entrada
hora = int(input("Digite o valor da hora"))
min = int(input("Digite os minutos trabalhados"))
valorpagohora = float(input("Digite o valor pago por hora"))
#processamento
convertido = hora +(min/60)
salario = convertido *valorpagohora
resultado = salario+(salario*70/100)
#saida
print(f"o valor do seu salario com hora extra, feito com base em:{convertido} horas é R${resultado}")
# Out:
# Digite o valor da hora15
# Digite os minutos trabalhados45
# Digite o valor pago por hora25
# o valor do seu salario com hora extra, feito com base em:15.75 horas é R$669.375

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # outro teste de mesa

# %%
#entrada
hora = int(input("Digite o valor da hora"))
min = int(input("Digite os minutos trabalhados"))
valorpagohora = float(input("Digite o valor pago por hora"))
#processamento
convertido = hora + (min/60)
salario = convertido *valorpagohora
resultado = salario +(salario*70/100)
#saida
print(f"o valor do seu salario com hora extra, feito com base em:{convertido} horas é {resultado}")
# Out:
# Digite o valor da hora20
# Digite os minutos trabalhados0
# Digite o valor pago por hora25
# o valor do seu salario com hora extra, feito com base em:20.0 horas é 850.0

# %% [markdown]
# # 4) Simulação de Investimento em CDB com Juros Compostos
#
# Uma pessoa deseja investir um valor em um CDB que rende uma taxa fixa de X% ao ano. Escreva um algoritmo que solicite o valor inicial do investimento, a taxa de juros anual (em %) e o período em anos. Depois, calcule o montante final considerando juros compostos.
#
#  Fórmula dos juros compostos:
#
# M=C×(1+i)**t (O t é potência)
#
# onde:
#
# M = montante final (valor após os anos de investimento)
#
# C = capital inicial (valor investido)
#
# i = taxa de juros anual (em decimal, ou seja, 5% = 0.05)
#
# t = tempo em anos
#
# Exemplo:
#
# Valor investido: R$ 1.000,00
#
# Taxa de juros: 6% ao ano (0.06)
#
# Tempo: 5 anos
#
# Valor final após 5 anos: R$ 1.338,23

# %%
#entrada
valorinicial=int(input("digite o valorinicial"))
taxajuros = float(input("digite a taxajuros"))
tempo=int(input("digite o tempo"))
#processamento
convertido=(taxajuros/100)
montante = valorinicial*(1+convertido)**tempo
#saida
print(f"o montante é:{montante}")
# Out:
# digite o valorinicial 1000
# digite a taxajuros 6
# digite o tempo 5
# o montante é:1338.2255776000002

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #5) Divisão de Conta em um Restaurante com Gorjeta
#
# Um grupo de amigos foi a um restaurante e deseja dividir a conta igualmente entre eles. Além disso, o restaurante cobra uma taxa de serviço de 10% sobre o valor total da conta mais uma gorjeta.
#
# Escreva um algoritmo que solicite o valor da conta e o número de pessoas no grupo. Depois, calcule o valor total com a taxa de serviço e quanto cada pessoa deve pagar.
#
#  Fórmulas:
#
# Definição da Gorjeta: Solicitar valor Gorjeta
#
# Taxa de serviço: Aplicar 10% da taxa de serviço do restaurante, somar ao valor total e depois somar a gorjeta, já que o garçom foi muito solicito;
#
# Valor por pessoa: Dividor pelo numero de pessoas
#
#  Exemplo:
#
# Valor da conta: R$ 200,00
#
# Valor da Gorjeta: R$ 50,00
#
# Número de pessoas: 4
#
# Taxa de serviço (10% de R$ 200,00): R$ 20,00
#
# Valor total a ser pago: R$ 220,00
#
# Valor com a Gorjeta: R$270,00
#
# Valor por pessoa: R$ 67,50

# %%
#entrada
gorjeta= float(input("digite o valor da gorjeta"))
taxaservico = float(input("digite o valor da taxaservico"))
numeropessoas=int(input("digite o numero de pessoas"))
valorconta=float(input("digite o valorconta"))
#processamento
valortotal=(taxaservico/100)*valorconta+valorconta
valorgorjeta=((taxaservico/100)*valorconta+valorconta)+gorjeta
valorpessoa=((taxaservico/100)*valorconta+valorconta+gorjeta)/numeropessoas
#saida
print(f"o valor total a ser pago é:{valortotal}")
print(f"o valor total com a gorjeta é:{valorgorjeta}")
print(f"o valor por pessoa é:{valorpessoa}")
# Out:
# digite o valor da gorjeta50
# digite o valor da taxaservico10
# digite o numero de pessoas4
# digite o valorconta200
# o valor total a ser pago é:220.0
# o valor total com a gorjeta é:270.0
# o valor por pessoa é:67.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
