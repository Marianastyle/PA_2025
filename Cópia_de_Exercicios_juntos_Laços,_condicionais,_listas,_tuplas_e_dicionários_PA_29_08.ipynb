# %% [markdown]
# <a href="https://colab.research.google.com/github/Marianastyle/PA_2025/blob/main/C%C3%B3pia_de_Exercicios_juntos_La%C3%A7os%2C_condicionais%2C_listas%2C_tuplas_e_dicion%C3%A1rios_PA_29_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lista de Exercícios unindo tudo que foi ensinado até o momento:
#
#
# *   Condicionais
# *   Laços de Reptição
# *   Listas
# *   Tuplas
# *   Dicionários
# *   Manipulação de Strings

# %% [markdown]
# # Tuplas - Acesso e Desempacotamento
#
# 1) Crie uma tupla contendo três tipos diferentes de dados: um número, uma string e uma lista. Use um laço de repetição para acessar e imprimir cada item da tupla. Além disso, dentro do laço, acesse e imprima o segundo item da lista que está dentro da tupla.

# %%
dados = (24, "Cíntia",[1,2,3])
for i in dados:
  print(i)
  segundoitem = dados[2][1]
print(f"O segundo item é: {segundoitem}")
# Out:
# 24
# Cíntia
# [1, 2, 3]
# O segundo item é: 2

# %%
# Out:
# tuple

# %% [markdown]
# # Dicionários - Criação e Acesso
# ## Cadastro de Pessoas e Análise de Alturas
# 2) Solicite ao usuário para inserir o nome e a altura de várias pessoas. Preencha um dicionário com essas informações e depois encontre e imprima o nome e a altura da pessoa mais alta e da mais baixa.

# %%
alturas = {}
print("digite os nomes e as alturas em metros e digite 'acabou os nomes' para parar: ")
continuarloop= True
while continuarloop:
  name=str(input("digite seu nome: "))
  if name.lower() =='acabou os nomes':
     continuarloop= False
  else:
    height=(input(f"digite sua altura: "))
    alturas[name]=height
if not alturas:
  print("dicionario vazio")
else:
  maisbaixa=min(alturas,key=alturas.get)
  maisalta=max(alturas,key=alturas.get)

  print("a pessoa mais baixa é: ",maisbaixa)
  print("a pessoa mais alta é: ",maisalta)
# Out:
# digite os nomes e as alturas em metros e digite 'acabou os nomes' para parar:
# digite seu nome: ana
# digite sua altura: 1.0
# digite seu nome: camila
# digite sua altura: 2.0
# digite seu nome: cecilia
# digite sua altura: 1.5
# digite seu nome: acabou os nomes
# a pessoa mais baixa é:  ana
# a pessoa mais alta é:  camila

# %% [markdown]
# # Lista, laços e Condicionais
# 3) Descrição: Crie uma listacom cinco números inteiros. Use um laço de repetição e uma condicional para imprimir apenas os números que são múltiplos de 3.

# %%
lista=[0,1,3,4,6]
for i in lista:
  if i % 3 == 0:
    print(f"Ok o número: {i} é multiplo de 3")
# Out:
# Ok o número: 0 é multiplo de 3
# Ok o número: 3 é multiplo de 3
# Ok o número: 6 é multiplo de 3

# %% [markdown]
# # Manipulação de Strings e Condicionais
# 4) Descrição: Crie uma string com uma frase. Use uma condicional para verificar se a frase contém a palavra "Python". Se sim, substitua a palavra "Python" por "programação" e imprima a nova frase.

# %%
frase= "ela adora Python"
if "Python" in frase:
  frasenova= frase.replace("Python","programação")
  print(f"A frase nova é: {frasenova}")
else:
  print("Não contem Python")
# Out:
# A frase nova é: ela adora programação

# %% [markdown]
# # Simulação de Alfândega com Cadastro Dinâmico de Itens usando dicionário
# 5) Simule uma situação de alfândega onde o funcionário cadastra itens novos encontrados na mala de uma pessoa que veio de uma viagem internacional. Após o cadastro de todos os itens, o programa imprime uma nota com todos os itens e seus preços, calcula o valor total e, se o valor total ultrapassar 500 dólares, calcula o valor de 60% a ser pago.

# %%
cadastro={}
print("digite o nome do item e o preço e digite 'acabou os itens' para parar: ")
nameitem = ""
while nameitem.lower() !='acabou os itens':
  nameitem=input("Digite o nome do item: ")
  if nameitem.lower() !='acabou os itens':
    priceitem=input("Digite o preço do item: ")
    cadastro[nameitem] = priceitem
if not cadastro:
  print("nenhum item")
else:
  total= 0
  for name, price in cadastro.items():
    total += float(price)
    print(f"Item {name}, preço {price} dolares")
    print(f"Valor total: {total:.2f}")
    valortotal= 500
  if total > valortotal:
    imposto= total*0.60
    print(f"Valor imposto: {imposto}")
    print(f"Valor a pagar: {total + imposto}")
  else:
    print("Valor abaixo de 500 dolares!")
# Out:
# digite o nome do item e o preço e digite 'acabou os itens' para parar:
# Digite o nome do item: banana
# Digite o preço do item: 20
# Digite o nome do item: maçã
# Digite o preço do item: 10
# Digite o nome do item: carne
# Digite o preço do item: 500
# Digite o nome do item: acabou os itens
# Item banana, preço 20 dolares
# Valor total: 20.00
# Item maçã, preço 10 dolares
# Valor total: 30.00
# Item carne, preço 500 dolares
# Valor total: 530.00
# Valor imposto: 318.0
# Valor a pagar: 848.0

# %% [markdown]
# # Identificação de Palavras Negativas em um Texto
# 6) Você vai criar um programa em Python para analisar um texto e identificar palavras que expressam pensamentos negativos. Para isso, você usará uma lista de palavras negativas fornecida e verificará quais dessas palavras estão presentes no texto fornecido pelo usuário. Exemplo de palavras negtivas, acrescente mais na lista: # Lista de palavras negativas palavras_negativas = ['triste', 'deprimido', 'ansioso', 'desapontado', 'frustrado']

# %%
texto=input("Digite um texto: ").lower()
texto1=texto.split()

palavrasnegencontradas=[]
palavras_negativas = ['triste', 'deprimido', 'ansioso', 'desapontado', 'frustrado','horrivel','irritante']
for i in texto1:
  texto2=i.strip()
  if i in palavras_negativas:
    palavrasnegencontradas.append(i)
if palavrasnegencontradas:
  print(f"As palavra negativas são: {palavrasnegencontradas}")

else:
  print("Nenhuma palavra negativa")
# Out:
# Digite um texto: ele ficou ansioso para a festa de sabado e depois triste e desapontado por nao poder ir pois tinha um compromissso marcado na mesma hora
# As palavra negativas são: ['ansioso', 'triste', 'desapontado']
